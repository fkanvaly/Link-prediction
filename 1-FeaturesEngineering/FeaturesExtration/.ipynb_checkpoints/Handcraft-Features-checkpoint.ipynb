# %%
import networkx as nx
import numpy as np
import pandas as pd
import pandas_profiling as pp
from tqdm import tqdm
import os
import json

# %% [markdown]
# # Load Data

# %% [markdown]
# ### Load training/testing edges and Graph

# %%
from LoadData import load

G, train, test, disconnected = load()

# %% [markdown]
# # Features Extraction

# %% [markdown]
# ### Precompute some elements need for features

# %%
from GraphFeatures import GraphFeaturesExtractor, precomputeData

precompute = precomputeData(G, recompute=False)
GFE = GraphFeaturesExtractor(G, precompute)

# %%
features = {"3-level": [],
                "1-level": ["jc", "cn", "aa", "pa", "cos", "s_out", "s_in", "t_in", "t_out", "pr_s", "pr_t",
                            "katz_s", "katz_t", "hubs_s", "hubs_t", "auto_s",
                            "auto_t", "sweight_out", "tweight_in", "weight_f1",
                            "weight_f2", "power_low", "short_path", "clust_coef_s", 
                            "clust_coef_t", "inf" ]}

GFE.set_features(features)

# %% [markdown]
# ### Compute Embedding

# %%
# training data
X_train = []
for i in tqdm(range(train.shape[0])):
    X_train.append(GFE.getFeatures(train[i,:2]))
X_train = np.vstackck(X_train)
y = np.array(list(map(int,training_set[:,2])))
np.save("X_train", X_train)
np.save("y_train", y_train)
# Out:
#   0%|          | 49/453797 [00:39<101:35:20,  1.24it/s]/home/kanva/deep3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/kanva/deep3/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   0%|          | 51/453797 [00:41<101:36:42,  1.24it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1690564c7eb6> in <module>()
#       2 X_train = []
#       3 for i in tqdm(range(train.shape[0])):
# ----> 4     X_train.append(GFE.getFeatures(train[i,:2]))
#       5 X_train = np.vstackck(X_train)
#       6 y = np.array(list(map(int,training_set[:,2])))
#
# ~/Workspace/3A/INF554-ML1/Challenge/1-FeaturesEngineering/FeaturesExtration/GraphFeatures.py in getFeatures(self, nodes, filters)
# ...

# %%
# test data
X_test = []
for i in tqdm(range(test.shape[0])):
    X_test.append(GFE.getFeatures(test[i,:2]))
X_test = np.vstack(X_test)
np.save('embeddings/X_test.npy', X_test)

# %% [markdown]
# # Features Selection & combination

# %%
X_train = np.load('embeddings/X_train.npy')
y_train = np.load('embeddings/y_train.npy')
df_X_train = pd.DataFrame(data=X_train, columns=features_name)

# %%
pp.ProfileReport(df=df_X_train)
# Out:
# /home/kanva/deep3/lib/python3.6/site-packages/astropy/stats/bayesian_blocks.py:434: RuntimeWarning: divide by zero encountered in log
#   return N_k * (np.log(N_k) - np.log(T_k))

# %% [markdown]
# ## Corelated variable

# %%
from feature_selector import FeatureSelector

# Features are in train and labels are in train_labels
fs = FeatureSelector(data = df_X_train, labels=y_train)

# %%
fs.identify_collinear(correlation_threshold = 0.98)
fs.plot_collinear(plot_all = True)
# Out:
# 9 features with a correlation magnitude greater than 0.98.

# %%
# list of collinear features to remove
collinear_features = fs.ops['collinear']

# dataframe of collinear features
fs.record_collinear.head()
# Out:
#    drop_feature corr_feature  corr_value
# 0        hubs_s        s_out    0.997176
# 1           inf          ded    1.000000
# 2        katz_s         pr_s    1.000000
# 3        katz_t         pr_t    1.000000
# 4  st_inter_out         aa_d    0.987825

# %% [markdown]
# ## Zero Importance Features

# %%
# Pass in the appropriate parameters
fs.identify_zero_importance(task = 'classification', 
                            eval_metric = 'auc', 
                            n_iterations = 10, 
                            early_stopping = True)

# list of zero importance features
zero_importance_features = fs.ops['zero_importance']
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's auc: 0.996267	valid_0's binary_logloss: 0.0748827
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's auc: 0.996186	valid_0's binary_logloss: 0.0755015
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's auc: 0.996252	valid_0's binary_logloss: 0.0750691
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's auc: 0.996294	valid_0's binary_logloss: 0.0750286
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's auc: 0.99628	valid_0's binary_logloss: 0.0746262
# ...

# %%
# plot the feature importances
fs.plot_feature_importances(threshold = 0.99, plot_n = 12)
# Out:
# 24 features required for 0.99 of cumulative importance

# %%
fs.identify_low_importance(cumulative_importance = 0.99)
fs.feature_importances.head(10)
# Out:
# 23 features required for cumulative importance of 0.99 after one hot encoding.
# 4 features do not contribute to cumulative importance of 0.99.
#      feature  importance  normalized_importance  cumulative_importance
# 0     hubs_s      3959.0               0.132059               0.132059
# 1     auto_t      3713.5               0.123870               0.255929
# 2       pr_t      3485.5               0.116265               0.372194
# 3       pr_s      2393.5               0.079839               0.452033
# 4     hubs_t      2152.1               0.071787               0.523820
# 5      s_out      1945.6               0.064899               0.588719
# 6     auto_s      1939.9               0.064709               0.653427
# 7         pa      1836.0               0.061243               0.714670
# 8  weight_f1      1326.0               0.044231               0.758901
# 9  weight_f2      1253.6               0.041816               0.800717

# %% [markdown]
# ## Single Unique Value Features

# %%
fs.identify_single_unique()
# Out:
# 0 features with a single unique value.

# %% [markdown]
# ## Removing Features

# %%
# train_removed = fs.remove(methods = 'all')
